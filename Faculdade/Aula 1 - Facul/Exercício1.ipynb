# %%
#Exercício 1
#Variaveis
a = 10
b = 5


print(" \n Exercícios \n\n ")
print("a = 10 \nb = 5")
print("Resposta a + b = ", a+b)
print("Resposta a - b = ", a-b)
print("Resposta a * b = ", a*b)
print("Resposta a // b = ", a//b)
print("Resposta a % b = ", a%b)
print("-----------------------------------")

#Variaveis
a = 0
b = 3

print("a = 0 \nb = 3")
print("Resposta a + b = ", a+b)
print("Resposta a - b = ", a-b)
print("Resposta a * b = ", a*b)
print("Resposta a // b = ", a//b)
print("Resposta a % b = ", a%b)
print("-----------------------------------")

#Variaveis
a = 10
b = -3

print("a = 10 \nb = -3")
print("Resposta a + b = ", a+b)
print("Resposta a - b = ", a-b)
print("Resposta a * b = ", a*b)
print("Resposta a // b = ", a//b)
print("Resposta a % b = ", a%b)
print("-----------------------------------")

#Variaveis
a = -10
b = 3

print("a = -10 \nb = 3")
print("Resposta a + b = ", a+b)
print("Resposta a - b = ", a-b)
print("Resposta a * b = ", a*b)
print("Resposta a // b = ", a//b)
print("Resposta a % b = ", a%b)
print("-----------------------------------")

#Variaveis
a = -10
b = -3

print("a = -10 \nb = -3")
print("Resposta a + b = ", a+b)
print("Resposta a - b = ", a-b)
print("Resposta a * b = ", a*b)
print("Resposta a // b = ", a//b)
print("Resposta a % b = ", a%b)
print("-----------------------------------")
# Out:
#
#  Exercícios
#
#
# a = 10
# b = 5
# Resposta a + b =  15
# Resposta a - b =  5
# Resposta a * b =  50
# Resposta a // b =  2
# Resposta a % b =  0
# -----------------------------------
# a = 0
# b = 3
# Resposta a + b =  3
# Resposta a - b =  -3
# Resposta a * b =  0
# Resposta a // b =  0
# Resposta a % b =  0
# -----------------------------------
# a = 10
# b = -3
# Resposta a + b =  7
# Resposta a - b =  13
# Resposta a * b =  -30
# Resposta a // b =  -4
# Resposta a % b =  -2
# -----------------------------------
# a = -10
# b = 3
# Resposta a + b =  -7
# Resposta a - b =  -13
# Resposta a * b =  -30
# Resposta a // b =  -4
# Resposta a % b =  2
# -----------------------------------
# a = -10
# b = -3
# Resposta a + b =  -13
# Resposta a - b =  -7
# Resposta a * b =  30
# Resposta a // b =  3
# Resposta a % b =  -1
# -----------------------------------

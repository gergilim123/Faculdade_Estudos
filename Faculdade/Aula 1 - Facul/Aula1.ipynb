# %%
print("Primeira aula, Pyhton.")
# Programa p/ calculos matemáticos
print("Primeira tabela")

#Exemplo Professor
#Variaveis
a = 10
b = 5

print("Resposta a + b = ", a+b)
print("Resposta a + b = " + str(a+b))

print (" xxxxxx \n \n cccccc")

#Exercício 1
#Variaveis
a = 10
b = 5

print("Resposta a + b = ", a+b)
print("Resposta a - b = ", a-b)
print("Resposta a * b = ", a*b)
print("Resposta a // b = ", a//b)
print("Resposta a % b = ", a%b)
print("-----------------------------------")

print("Resposta a + b = ", a+b)
print("Resposta a + b = ", a+b)
print("Resposta a + b = ", a+b)
print("Resposta a + b = ", a+b)
print("Resposta a + b = ", a+b)



#--------------------------------------------------------------------------------------------------------------------------------------------


#Parte 2, trabalha do com Floats
#Atribua um número real para a variável valor e escreva algumas operações:

#Variáveis

valor = 99.99
multa = valor * 0.02
juros = valor * 0.00033



print("multa = ", multa)

print("juros = R$", juros)

print("R$", format(juros, '.2f'))
print("\n \n \n \n \n ")


#Multa 2% do valor da fatura

valor = 100
multa = 0.02
valor_multa_fatura = valor*multa

print("Multa: R$", format(valor_multa_fatura, '.2f'))


print("O segundo parâmetro é um objeto do tipo <int> com o valor ", 10)
# Out:
# Primeira aula, Pyhton.
# Primeira tabela
# Resposta a + b =  15
# Resposta a + b = 15
#  xxxxxx
#
#  cccccc
# Resposta a + b =  15
# Resposta a - b =  5
# Resposta a * b =  50
# Resposta a // b =  2
# Resposta a % b =  0
# -----------------------------------
# Resposta a + b =  15
# Resposta a + b =  15
# Resposta a + b =  15
# Resposta a + b =  15
# Resposta a + b =  15
# multa =  1.9998
# juros = R$ 0.0329967
# R$ 0.03
#
#
#
#
#
#
# Multa: R$ 2.00
# O segundo parâmetro é um objeto do tipo <int> com o valor  10
